# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 15.95 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
# !pip install -r /content/OIDv4_ToolKit/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 3.4MB 4.8MB/s
# ...
#      |████████████████████████████████| 552kB 49.9MB/s
# ...
#      |████████████████████████████████| 71kB 5.6MB/s
# ...
#      |████████████████████████████████| 6.7MB 48.6MB/s
# ...
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: botocore 1.19.10 has requirement urllib3<1.26,>=1.25.4; python_version != "3.4", but you'll have urllib3 1.24.3 which is incompatible.
# ...
#   Found existing installation: docutils 0.16
#     Uninstalling docutils-0.16:
#       Successfully uninstalled docutils-0.16
#   Found existing installation: rsa 4.6
#     Uninstalling rsa-4.6:
#       Successfully uninstalled rsa-4.6
# ...

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes 'Vehicle registration plate' --type_csv train --limit 1500
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Vehicle registration plate.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...145%, 0 MB, 49708 KB/s, 0 seconds passed
# ...

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes 'Vehicle registration plate' --type_csv validation --limit 300
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Vehicle registration plate.
#    [ERROR] | Missing the validation-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...100%, 16 MB, 14636 KB/s, 1 seconds passed
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 修正/content/drive/'My Drive'/yolo/data/classes.txt下載類別

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !cp /content/drive/'My Drive'/yolo/data/classes.txt  /content/

# %%
# !cp /content/drive/'My Drive'/yolo/data/convert_annotations.py  /content/OIDv4_ToolKit/
# !python /content/OIDv4_ToolKit/convert_annotations.py
# Out:
# Currently in subdirectory: validation
# Converting annotations for class:  Vehicle registration plate
# 100% 300/300 [00:06<00:00, 47.62it/s]
# Currently in subdirectory: train
# Converting annotations for class:  Vehicle registration plate
# 100% 1500/1500 [00:32<00:00, 46.06it/s]

# %%
# !rm -r /content/OID/Dataset/train/'Vehicle registration plate'/Label/

# %%
# !rm -r /content/OID/Dataset/validation/'Vehicle registration plate'/Label/

# %%
# !ln -s /content/OID/Dataset/train/'Vehicle registration plate'/ obj

# %%
# !ln -s /content/OID/Dataset/validation/'Vehicle registration plate'/ test

# %%
# !zip -r obj.zip obj
# Out:
#   adding: obj/ (stored 0%)
#   adding: obj/6e89abd329ad9e1d.txt (deflated 57%)
#   adding: obj/1ddce781187a39d5.jpg (deflated 0%)
#   adding: obj/720d44578b9dd447.jpg (deflated 0%)
#   adding: obj/4c4b5a8db160e135.txt (deflated 47%)
#   adding: obj/5ea14bd6656e7430.txt (deflated 50%)
#   adding: obj/1759271e6348f3b4.txt (deflated 34%)
#   adding: obj/6b3fa7c35b2aeb97.jpg (deflated 4%)
#   adding: obj/2e893e0c6aaefa86.jpg (deflated 0%)
#   adding: obj/0f131b8d6b8c0f56.txt (deflated 48%)
#   adding: obj/436449137d4d025b.jpg (deflated 0%)
#   adding: obj/952e7b4c05aff6a5.jpg (deflated 0%)
#   adding: obj/9427a9c480ef4277.jpg (deflated 0%)
#   adding: obj/414c40a5f38d1bee.txt (deflated 32%)
#   adding: obj/ee2fe9ac5b387fba.jpg (deflated 0%)
#   adding: obj/8d83f4730a92a89e.jpg (deflated 0%)
#   adding: obj/fe73094afb57502b.txt (deflated 47%)
#   adding: obj/93db3cb0d8bed9fb.txt (deflated 35%)
#   adding: obj/da3c348a57e8a784.jpg (deflated 0%)
# ...

# %%
# !zip -r test.zip test
# Out:
#   adding: test/ (stored 0%)
#   adding: test/30b6cfb60bf44533.jpg (deflated 0%)
#   adding: test/1eb2ebab9cd7adf6.jpg (deflated 0%)
#   adding: test/e6299b9e04680adb.txt (deflated 59%)
#   adding: test/28bd6c6b1050e055.txt (deflated 21%)
#   adding: test/b15d6c0bdf90226d.jpg (deflated 0%)
#   adding: test/ce97f7bc90e97109.txt (deflated 32%)
#   adding: test/7b4e86e1c94d65de.txt (deflated 38%)
#   adding: test/03b7b71e1ffcb7a8.jpg (deflated 0%)
#   adding: test/f73b754cdb1ab677.txt (deflated 34%)
#   adding: test/de2b5afb7eda96cf.txt (deflated 46%)
#   adding: test/a52079c6cc4050cd.jpg (deflated 0%)
#   adding: test/302d636c896c263f.txt (deflated 35%)
#   adding: test/ccc1a2d44a290368.txt (deflated 29%)
#   adding: test/99732f172ac80128.jpg (deflated 0%)
#   adding: test/da1352ab6054a2e4.jpg (deflated 0%)
#   adding: test/d8f6c135ec5486ff.txt (deflated 32%)
#   adding: test/00723dac8201a83e.jpg (deflated 0%)
#   adding: test/a823532e163f5722.jpg (deflated 0%)
# ...

# %%
# !cp /content/obj.zip /content/drive/'My Drive'/yolo/data/

# %%
# !cp /content/test.zip /content/drive/'My Drive'/yolo/data/
