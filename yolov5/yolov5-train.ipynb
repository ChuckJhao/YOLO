# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -qr yolov5/requirements.txt  # install dependencies (ignore errors)
# %cd yolov5
 
import torch
from IPython.display import Image, clear_output  # to display images
from utils.google_utils import gdrive_download  # to download models/datasets
 
clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.7.0+cu101 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/'My Drive'/yolo/data
# Out:
# classes.txt		datadownloadv4.ipynb  obj.zip	 test.zip
# convert_annotations.py	datadownloadv5.ipynb  plate.zip

# %%
# copy over both datasets into the root directory of the Colab VM (comment out test.zip if you are not using a validation dataset)
# !cp /content/drive/'My Drive'/yolo/data/plate.zip /content

# %%
# unzip the datasets and their contents so that they are now in /content/darknet/data/ folder
# !unzip /content/plate.zip -d /content/
# Out:
# Archive:  /content/plate.zip
#    creating: /content/plate/
#    creating: /content/plate/labels/
#    creating: /content/plate/labels/train/
#   inflating: /content/plate/labels/train/bf5c6541e1856d71.txt
#   inflating: /content/plate/labels/train/71e40eddd38b2f18.txt
#   inflating: /content/plate/labels/train/4440a00600338234.txt
#   inflating: /content/plate/labels/train/a4e7188c8b0d3cde.txt
#   inflating: /content/plate/labels/train/a8219236525579fb.txt
#   inflating: /content/plate/labels/train/0063e41b53567829.txt
#   inflating: /content/plate/labels/train/adc8ba3938d94dce.txt
#   inflating: /content/plate/labels/train/d70f0e381aa203a6.txt
#   inflating: /content/plate/labels/train/81bc836225e84607.txt
#   inflating: /content/plate/labels/train/1bdde97c17e70da1.txt
#   inflating: /content/plate/labels/train/1f25582e8b2cd7c2.txt
#   inflating: /content/plate/labels/train/82f4260758844966.txt
#   inflating: /content/plate/labels/train/381233ba551661ad.txt
# ...

# %%
# !python train.py --img 512 --batch 16 --epochs 10 --data '/content/drive/My Drive/yolo/yolov5/plate.yaml' --cfg '/content/drive/My Drive/yolo/yolov5/yolov5x.yaml' --weights yolov5x.pt --name ''
# Out:
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='/content/drive/My Drive/yolo/yolov5/yolov5x.yaml', data='/content/drive/My Drive/yolo/yolov5/plate.yaml', device='', epochs=10, evolve=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[512, 512], local_rank=-1, log_imgs=10, logdir='runs/', multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=16, weights='yolov5x.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/", view at http://localhost:6006/
# 2020-11-06 07:01:19.280188: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Install Weights & Biases for experiment logging via 'pip install wandb' (recommended)
# ...

# %%
# !python detect.py --weights runs/exp1/weights/best.pt --img 512 --conf 0.5 --source '/content/drive/My Drive/yolo/yolov5/plates.jpg'
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', img_size=512, iou_thres=0.45, save_conf=False, save_dir='inference/output', save_txt=False, source='/content/drive/My Drive/yolo/yolov5/plates.jpg', update=False, view_img=False, weights=['runs/exp1/weights/best.pt'])
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Fusing layers...
# Model Summary: 284 layers, 8.83906e+07 parameters, 0 gradients
# image 1/1 /content/drive/My Drive/yolo/yolov5/plates.jpg: 224x512 2 plates, Done. (0.034s)
# Results saved to inference/output
# Done. (0.269s)

# %%
# !cp runs/exp1/weights/best.pt '/content/drive/My Drive/yolo/yolov5/'

# %% [markdown]
# Reference: https://github.com/ultralytics/yolov5

# %% [markdown]
# #Kaggle copy and edit https://www.kaggle.com/vin1234/gettingstarted-with-yolov5-global-wheat-detection
